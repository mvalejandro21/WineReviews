# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../data/raw-winemag-data-130k-v2.csv')

df.shape
# Out:
# (129971, 14)

# %%
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Mapa de calor de valores nulos")
plt.show()

# %%
df_model = df[['price', 'points', 'country', 'province', 'variety', 'winery']].copy()

# Eliminamos filas con precio faltante para entrenamiento
df_model = df_model.dropna(subset=['price'])

# One-hot encoding para categóricas
df_model_encoded = pd.get_dummies(df_model, drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_model = df[['price', 'points', 'country', 'province', 'variety', 'winery']].copy()
#       3 # Eliminamos filas con precio faltante para entrenamiento
#       4 df_model = df_model.dropna(subset=['price'])
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum().sort_values(ascending=False).plot(kind='bar', figsize=(12, 6))
plt.title("Valores nulos por columna")
plt.xlabel("Columnas")
plt.ylabel("Cantidad de valores nulos")
plt.show()

"porcentaje de nulos en precio"
df['price'].isnull().mean() * 100

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['points'] = pd.to_numeric(df['points'], errors='coerce')

# Lista de columnas numéricas
columnas_numericas = ['price', 'points']

# Graficar boxplots para cada columna numérica
for col in columnas_numericas:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col], color='tomato')
    plt.title(f'Detección de Outliers - {col}')
    plt.xlabel(col)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
df[df['points'] == 100]
# Out:
#         Unnamed: 0    country  \
# 345            345  Australia
# 7335          7335      Italy
# 36528        36528     France
# 39286        39286      Italy
# 42197        42197   Portugal
# 45781        45781      Italy
# 45798        45798         US
# 58352        58352     France
# 89728        89728     France
# 89729        89729     France
# 111753      111753     France
# 111754      111754      Italy
# 111755      111755     France
# 111756      111756     France
# 113929      113929         US
# 114972      114972   Portugal
# 118058      118058         US
# 122935      122935     France
# 123545      123545         US
#
#                                               description  \
# 345     This wine contains some material over 100 year...
# 7335    Thick as molasses and dark as caramelized brow...
# 36528   This is a fabulous wine from the greatest Cham...
# 39286   A perfect wine from a classic vintage, the 200...
# ...

# %%
for col in columnas_numericas:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower) | (df[col] > upper)]
    
    print(f"{col}: {len(outliers)} outliers detectados")
# Out:
# price: 7241 outliers detectados
# points: 52 outliers detectados
